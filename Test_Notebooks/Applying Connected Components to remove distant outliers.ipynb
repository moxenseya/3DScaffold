# %% [markdown]
# # Notebook for Filters and Thresholding

# %% [markdown]
# First we import the required libraries

# %%
# import PIL
from PIL import Image
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
import numpy
#import tifffile
import os

import skimage

from skimage import data
from skimage.io import imsave

from skimage.filters import threshold_otsu

# %% [markdown]
# Next, we Initialize our array and we load our images into it

# %%
raw_ct_scan_array = []

for fname in os.listdir('img/'):

        im = Image.open(os.path.join('img/',fname))
        imarray = numpy.array(im)
        raw_ct_scan_array.append(imarray)

raw_ct_scan_array = numpy.asarray(raw_ct_scan_array, dtype='uint8')

# %% [markdown]
# We can check our array using the shape attribute

# %% [markdown]
# In case color's don't work
# (Source: https://stackoverflow.com/questions/38709618/rgb-values-being-returned-by-pil-dont-match-rgb-color,
#
# for reference: https://www.pyimagesearch.com/2014/11/03/display-matplotlib-rgb-image/)

# %%
raw_ct_scan_array.shape
# Out:
# (344, 1024, 1024)

# %% [markdown]
# We'll create a testfig placeholder variable that will contain the slice we want to test with.

# %%
testfig = raw_ct_scan_array[250]

# %% [markdown]
# Here's a sample of our images that we are using for testing filters

# %%
plt.figure(figsize=(10,10))
plt.imshow(testfig,cmap="gray")

# %%
numpy.max(testfig)
# Out:
# 188

# %% [markdown]
# First, we try with the Bilateral Filter. It has a sigma spatial parameter that we need to tune.

# %%
plt.figure(figsize=(10,10))
# %time bilateral=skimage.restoration.denoise_bilateral(testfig,multichannel=False, win_size=9)
plt.imshow(bilateral,cmap='gray')
numpy.max(bilateral)
# Out:
# Wall time: 1.34 s
# 0.7119864926108282

# %% [markdown]
# Here's how to see the difference between the original and the filtered images

# %%
plt.figure(figsize=(10,10))
plt.imshow(abs(testfig-255*bilateral),cmap='gray')

# %% [markdown]
# Applying Otsu threshold on the above slice, we get the following output:

# %%
threshold_otsu(bilateral)
# Out:
# 0.262823138873919

# %%
plt.figure(figsize=(10,10))
plt.imshow(bilateral > threshold_otsu(bilateral),cmap='gray')

# %% [markdown]
# Now, we try the Non-Local Means filter. It can work on 2D and 3D shaped nparrays. It works using a patch size parameter which we don't specify here.
#
# When we pass the 3D shape to the method, it freezes the PC and throws a memoryerror. Upon sending a 2D image, it does work.

# %%
nonlocalmeans_array = skimage.restoration.denoise_nl_means(fast_mode=True,image=testfig,multichannel=False)
plt.figure(figsize=(10,10))
#plt.imshow(nonlocalmeans_array, cmap = 'gray')

# %%
threshold_otsu(nonlocalmeans_array)
# Out:
# 69.99609375

# %% [markdown]
# Applying Otsu threshold on the above slice, we get the following output:

# %%
plt.figure(figsize=(10,10))
plt.imshow(nonlocalmeans_array > threshold_otsu(nonlocalmeans_array),cmap='gray')

# %% [markdown]
# Observation: Bilateral gives smoother and less noisy images when threshold is applied. We'll create two seperate sets of thresholded outputs.
#
#
# ---> Bilateral Filter and Threshold
#
# ---> Non Local Means and Threshold

# %% [markdown]
# Observation: Bilateral Filtered images have very low otsu threshold value. Non-Local Means has threshold values closer to the ones obtained without filters.

# %%
bilateral_array_with_otsu = bilateral > threshold_otsu(bilateral)

# %%
bilateral_array_with_otsu.shape
# Out:
# (1024, 1024)

# %%
plt.imshow(skimage.measure.label(bilateral_array_with_otsu))

# %% [markdown]
# Couldn't get it to save images in this format. Have manually exported for now, get them exported from the program later.

# %%
for img_index in range(99,102):
    bilateral_temp=skimage.restoration.denoise_bilateral(raw_ct_scan_array[img_index,:,:],multichannel=False, win_size=9)
    otsu_filtered_bilateral_temp= bilateral_temp > threshold_otsu(bilateral_temp)
    labeled_image = skimage.measure.label(otsu_filtered_bilateral_temp)
    im = Image.fromarray(numpy.uint8(labeled_image*255))
    plt.imshow(im)
    #im.save("Connected_components_Output/slice(%d) .png" % (img_index+1))
    #print("Exported slice %d!" % (img_index +1))

# %%
for img_index in range(0,344):
    bilateral_temp = skimage.restoration.denoise_bilateral(raw_ct_scan_array[img_index,:,:],multichannel=False,sigma_spatial=2)
    otsu_filtered_bilateral_temp= bilateral_temp > threshold_otsu(bilateral_temp)
    im = Image.fromarray(numpy.uint8(otsu_filtered_bilateral_temp*255))

    im.save("Bilateral_Filtered_Otsu_Output/slice(%d) .png" % (img_index+1))
    print("Exported slice %d!" % (img_index +1))
# Out:
# Exported slice 1!
# Exported slice 2!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ca7d97b44931> in <module>
#       1 for img_index in range(0,344):
# ----> 2     bilateral_temp = skimage.restoration.denoise_bilateral(raw_ct_scan_array[img_index],multichannel=False,sigma_spatial=2)
#       3     otsu_filtered_bilateral_temp= bilateral_temp > threshold_otsu(bilateral_temp)
#       4     im = Image.fromarray(numpy.uint8(otsu_filtered_bilateral_temp*255))
#       5
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\skimage\restoration\_denoise.py in denoise_bilateral(image, win_size, sigma_color, sigma_spatial, bins, mode, cval, multichannel)
#     115
#     116     return _denoise_bilateral(image, win_size, sigma_color, sigma_spatial,
# --> 117                               bins, mode, cval)
#     118
#     119
#
# skimage\restoration\_denoise_cy.pyx in skimage.restoration._denoise_cy._denoise_bilateral()
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# KeyboardInterrupt:

# %% [markdown]
# Importing all of our exported bilateral filtered Slices

# %%
bilateral_array = []

for fname in os.listdir('Bilateral_Filtered_Output/'):

        im = Image.open(os.path.join('Bilateral_Filtered_Output/',fname))
        imarray = numpy.array(im)
        bilateral_array.append(imarray)

bilateral_array = numpy.asarray(bilateral_array, dtype='uint8')

# %%
flattened_bilateral_array = bilateral_array.ravel()
otsu_bilateral_array = bilateral_array > threshold_otsu(flattened_bilateral_array)
for img_index in range(0,344):
    im = Image.fromarray(numpy.uint8(otsu_bilateral_array[img_index,:,:]*255))

    im.save("Bilateral_Filtered_Otsu_Output/slice(%d) .png" % (img_index+1))
    print("Exported slice %d!" % (img_index +1))
# Out:
# Exported slice 1!
# Exported slice 2!
# Exported slice 3!
# Exported slice 4!
# Exported slice 5!
# Exported slice 6!
# Exported slice 7!
# Exported slice 8!
# Exported slice 9!
# Exported slice 10!
# Exported slice 11!
# Exported slice 12!
# Exported slice 13!
# Exported slice 14!
# Exported slice 15!
# Exported slice 16!
# Exported slice 17!
# Exported slice 18!
# Exported slice 19!
# Exported slice 20!
# Exported slice 21!
# Exported slice 22!
# Exported slice 23!
# Exported slice 24!
# Exported slice 25!
# Exported slice 26!
# Exported slice 27!
# Exported slice 28!
# Exported slice 29!
# Exported slice 30!
# Exported slice 31!
# Exported slice 32!
# Exported slice 33!
# Exported slice 34!
# Exported slice 35!
# Exported slice 36!
# Exported slice 37!
# Exported slice 38!
# Exported slice 39!
# Exported slice 40!
# Exported slice 41!
# Exported slice 42!
# Exported slice 43!
# Exported slice 44!
# Exported slice 45!
# Exported slice 46!
# Exported slice 47!
# Exported slice 48!
# Exported slice 49!
# Exported slice 50!
# Exported slice 51!
# Exported slice 52!
# Exported slice 53!
# Exported slice 54!
# Exported slice 55!
# Exported slice 56!
# Exported slice 57!
# Exported slice 58!
# Exported slice 59!
# Exported slice 60!
# Exported slice 61!
# Exported slice 62!
# Exported slice 63!
# Exported slice 64!
# Exported slice 65!
# Exported slice 66!
# Exported slice 67!
# Exported slice 68!
# Exported slice 69!
# Exported slice 70!
# Exported slice 71!
# Exported slice 72!
# Exported slice 73!
# Exported slice 74!
# Exported slice 75!
# Exported slice 76!
# Exported slice 77!
# Exported slice 78!
# Exported slice 79!
# Exported slice 80!
# Exported slice 81!
# Exported slice 82!
# Exported slice 83!
# Exported slice 84!
# Exported slice 85!
# Exported slice 86!
# Exported slice 87!
# Exported slice 88!
# Exported slice 89!
# Exported slice 90!
# Exported slice 91!
# Exported slice 92!
# Exported slice 93!
# Exported slice 94!
# Exported slice 95!
# Exported slice 96!
# Exported slice 97!
# Exported slice 98!
# Exported slice 99!
# Exported slice 100!
# Exported slice 101!
# Exported slice 102!
# Exported slice 103!
# Exported slice 104!
# Exported slice 105!
# Exported slice 106!
# Exported slice 107!
# Exported slice 108!
# Exported slice 109!
# Exported slice 110!
# Exported slice 111!
# Exported slice 112!
# Exported slice 113!
# Exported slice 114!
# Exported slice 115!
# Exported slice 116!
# Exported slice 117!
# Exported slice 118!
# Exported slice 119!
# Exported slice 120!
# Exported slice 121!
# Exported slice 122!
# Exported slice 123!
# Exported slice 124!
# Exported slice 125!
# Exported slice 126!
# Exported slice 127!
# Exported slice 128!
# Exported slice 129!
# Exported slice 130!
# Exported slice 131!
# Exported slice 132!
# Exported slice 133!
# Exported slice 134!
# Exported slice 135!
# Exported slice 136!
# Exported slice 137!
# Exported slice 138!
# Exported slice 139!
# Exported slice 140!
# Exported slice 141!
# Exported slice 142!
# Exported slice 143!
# Exported slice 144!
# Exported slice 145!
# Exported slice 146!
# Exported slice 147!
# Exported slice 148!
# Exported slice 149!
# Exported slice 150!
# Exported slice 151!
# Exported slice 152!
# Exported slice 153!
# Exported slice 154!
# Exported slice 155!
# Exported slice 156!
# Exported slice 157!
# Exported slice 158!
# Exported slice 159!
# Exported slice 160!
# Exported slice 161!
# Exported slice 162!
# Exported slice 163!
# Exported slice 164!
# Exported slice 165!
# Exported slice 166!
# Exported slice 167!
# Exported slice 168!
# Exported slice 169!
# Exported slice 170!
# Exported slice 171!
# Exported slice 172!
# Exported slice 173!
# Exported slice 174!
# Exported slice 175!
# Exported slice 176!
# Exported slice 177!
# Exported slice 178!
# Exported slice 179!
# Exported slice 180!
# Exported slice 181!
# Exported slice 182!
# Exported slice 183!
# Exported slice 184!
# Exported slice 185!
# Exported slice 186!
# Exported slice 187!
# Exported slice 188!
# Exported slice 189!
# Exported slice 190!
# Exported slice 191!
# Exported slice 192!
# Exported slice 193!
# Exported slice 194!
# Exported slice 195!
# Exported slice 196!
# Exported slice 197!
# Exported slice 198!
# Exported slice 199!
# Exported slice 200!
# Exported slice 201!
# Exported slice 202!
# Exported slice 203!
# Exported slice 204!
# Exported slice 205!
# Exported slice 206!
# Exported slice 207!
# Exported slice 208!
# Exported slice 209!
# Exported slice 210!
# Exported slice 211!
# Exported slice 212!
# Exported slice 213!
# Exported slice 214!
# Exported slice 215!
# Exported slice 216!
# Exported slice 217!
# Exported slice 218!
# Exported slice 219!
# Exported slice 220!
# Exported slice 221!
# Exported slice 222!
# Exported slice 223!
# Exported slice 224!
# Exported slice 225!
# Exported slice 226!
# Exported slice 227!
# Exported slice 228!
# Exported slice 229!
# Exported slice 230!
# Exported slice 231!
# Exported slice 232!
# Exported slice 233!
# Exported slice 234!
# Exported slice 235!
# Exported slice 236!
# Exported slice 237!
# Exported slice 238!
# Exported slice 239!
# Exported slice 240!
# Exported slice 241!
# Exported slice 242!
# Exported slice 243!
# Exported slice 244!
# Exported slice 245!
# Exported slice 246!
# Exported slice 247!
# Exported slice 248!
# Exported slice 249!
# Exported slice 250!
# Exported slice 251!
# Exported slice 252!
# Exported slice 253!
# Exported slice 254!
# Exported slice 255!
# Exported slice 256!
# Exported slice 257!
# Exported slice 258!
# Exported slice 259!
# Exported slice 260!
# Exported slice 261!
# Exported slice 262!
# Exported slice 263!
# Exported slice 264!
# Exported slice 265!
# Exported slice 266!
# Exported slice 267!
# Exported slice 268!
# Exported slice 269!
# Exported slice 270!
# Exported slice 271!
# Exported slice 272!
# Exported slice 273!
# Exported slice 274!
# Exported slice 275!
# Exported slice 276!
# Exported slice 277!
# Exported slice 278!
# Exported slice 279!
# Exported slice 280!
# Exported slice 281!
# Exported slice 282!
# Exported slice 283!
# Exported slice 284!
# Exported slice 285!
# Exported slice 286!
# Exported slice 287!
# Exported slice 288!
# Exported slice 289!
# Exported slice 290!
# Exported slice 291!
# Exported slice 292!
# Exported slice 293!
# Exported slice 294!
# Exported slice 295!
# Exported slice 296!
# Exported slice 297!
# Exported slice 298!
# Exported slice 299!
# Exported slice 300!
# Exported slice 301!
# Exported slice 302!
# Exported slice 303!
# Exported slice 304!
# Exported slice 305!
# Exported slice 306!
# Exported slice 307!
# Exported slice 308!
# Exported slice 309!
# Exported slice 310!
# Exported slice 311!
# Exported slice 312!
# Exported slice 313!
# Exported slice 314!
# Exported slice 315!
# Exported slice 316!
# Exported slice 317!
# Exported slice 318!
# Exported slice 319!
# Exported slice 320!
# Exported slice 321!
# Exported slice 322!
# Exported slice 323!
# Exported slice 324!
# Exported slice 325!
# Exported slice 326!
# Exported slice 327!
# Exported slice 328!
# Exported slice 329!
# Exported slice 330!
# Exported slice 331!
# Exported slice 332!
# Exported slice 333!
# Exported slice 334!
# Exported slice 335!
# Exported slice 336!
# Exported slice 337!
# Exported slice 338!
# Exported slice 339!
# Exported slice 340!
# Exported slice 341!
# Exported slice 342!
# Exported slice 343!
# Exported slice 344!

# %%
threshold_otsu(flattened_bilateral_array)
# Out:
# 68

# %% [markdown]
# Now we apply thresholding by first doing ravel, and then exporting otsu thresholded output

# %% [markdown]
# Takes roughly 20 minutes to export all slices with bilateral filter.

# %% [markdown]
# # Test Section

# %% [markdown]
# # ----------------------------------------------------------------------------------

# %%
for i in range(0,344):
    print(threshold_otsu(raw_ct_scan_array[i]))
# Out:
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 68
# 69
# 69
# 69
# 68
# 68
# 68
# 68
# 68
# 68
# 69
# 69
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 69
# 69
# 69
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 67
# 67
# 67
# 67
# 67
# 67
# 68
# 68
# 68
# 68
# 68
# 69
# 69
# 69
# 69
# 69
# 69
# 69
# 68
# 69
# 69
# 69
# 69
# 69
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 73
# 73
# 73
# 73
# 73
# 73
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 71
# 71
# 71
# 71
# 71
# 70
# 70
# 70
# 70
# 70
# 70
# 69
# 69
# 69
# 68
# 68
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 66
# 65
# 65
# 64
# 64
# 62
# 62
# 61
# 59
# 58
# 58
# 56
# 54
# 53
# 52
# 9
# 9
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7

# %%
for i in range(0,344):
    print(threshold_otsu(skimage.restoration.denoise_bilateral(raw_ct_scan_array[i],multichannel=False,sigma_spatial=2)))
# Out:
# 0.02712054141479864
# 0.027106163653014798
# 0.027229481445636486
# 0.02734437331759361
# 0.027336262231712507
# 0.027384250719569028
# 0.027070548967956378
# 0.026720944816386212
# 0.0265210279169037
# 0.026023143061965282
# 0.02595891349120017
# 0.025871866621687493
# 0.026190143624748783
# 0.026052566706638986
# 0.025888651061497826
# 0.026139130099684472
# 0.026349422603251557
# 0.026314750881643107
# 0.026271386259625714
# 0.027203315832571635
# 0.0260114011901326
# 0.027058833004064205
# 0.027400409850267787
# 0.027037481915133367
# 0.027203196972053742
# 0.02733601626025963
# 0.027312891638839435
# 0.02689909622970499
# 0.027375231391677017
# 0.02710490964581038
# 0.027294175248997507
# 0.026983436679976304
# 0.027405262839962627
# 0.026927935746688076
# 0.027537157986209558
# 0.026585208254662915
# 0.026822774701149927
# 0.025887384539514807
# 0.027606042094094573
# 0.026607155047312724
# 0.026833336070958842
# 0.027084993476144334
# 0.027824049808993216
# 0.027618361118663743
# 0.027732613851938134
# 0.0279145036430445
# 0.026122375933490753
# 0.028521104345424392
# 0.027170304654496026
# 0.026995953805922256
# 0.026578142871933455
# 0.028628159519357342
# 0.028865906564962504
# 0.02671821438792797
# 0.26380820830442075
# 0.2714683954446977
# 0.27230423307037305
# 0.2738259084712424
# 0.2714715193000842
# 0.269373778188035
# 0.2697680660407158
# 0.27024771809860054
# 0.2700827031251606
# 0.27085618816288554
# 0.26817229365188355
# 0.2719186886702605
# 0.2726258092424034
# 0.2736001590516514
# 0.27434849056393373
# 0.27604834940556444
# 0.2772719916130896
# 0.2758535011433437
# 0.27727381429550185
# 0.2765889127368756
# 0.27303030069923684
# 0.2725439227544356
# 0.2716147997278946
# 0.2705259084207555
# 0.26788502175444207
# 0.2671230316030304
# 0.267819203602487
# 0.2662535951811418
# 0.26747786619775227
# 0.2682349571461018
# 0.2666960643937241
# 0.2654848778544501
# 0.26051468482730245
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-7810d20ff344> in <module>
#       1 for i in range(0,344):
# ----> 2     print(threshold_otsu(skimage.restoration.denoise_bilateral(raw_ct_scan_array[i],multichannel=False,sigma_spatial=2)))
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\skimage\restoration\_denoise.py in denoise_bilateral(image, win_size, sigma_color, sigma_spatial, bins, mode, cval, multichannel)
#     115
#     116     return _denoise_bilateral(image, win_size, sigma_color, sigma_spatial,
# --> 117                               bins, mode, cval)
#     118
#     119
#
# skimage\restoration\_denoise_cy.pyx in skimage.restoration._denoise_cy._denoise_bilateral()
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# KeyboardInterrupt:

# %%
for i in range(0,344):
    print(threshold_otsu(skimage.restoration.denoise_nl_means(fast_mode=True,image=raw_ct_scan_array[i],multichannel=False)))
# Out:
# 6.9609375
# 6.970703125
# 6.97265625
# 6.970703125
# 6.9609375
# 7.068359375
# 7.029296875
# 6.97265625
# 7.91015625
# 7.86328125
# 6.982421875
# 6.884765625
# 7.03125
# 6.93359375
# 6.93359375
# 6.982421875
# 7.03125
# 7.03125
# 7.03125
# 7.759765625
# 7.87109375
# 7.21875
# 6.986328125
# 7.029296875
# 7.06640625
# 7.068359375
# 6.970703125
# 6.97265625
# 6.970703125
# 6.97265625
# 6.970703125
# 6.970703125
# 6.91015625
# 6.986328125
# 7.91015625
# 7.921875
# 7.083984375
# 6.93359375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-2909e8735143> in <module>
#       1 for i in range(0,344):
# ----> 2     print(threshold_otsu(skimage.restoration.denoise_nl_means(fast_mode=True,image=raw_ct_scan_array[i],multichannel=False)))
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\skimage\restoration\non_local_means.py in denoise_nl_means(image, patch_size, patch_distance, h, multichannel, fast_mode, sigma)
#     143         if fast_mode:
#     144             return np.squeeze(
# --> 145                 np.asarray(_fast_nl_means_denoising_2d(image, **nlm_kwargs)))
#     146         else:
#     147             return np.squeeze(
#
# skimage\restoration\_nl_means_denoising.pyx in skimage.restoration._nl_means_denoising._fast_nl_means_denoising_2d()
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\numpy\core\numeric.py in zeros_like(a, dtype, order, subok)
#     147
#     148     """
# --> 149     res = empty_like(a, dtype=dtype, order=order, subok=subok)
#     150     # needed instead of a 0 to get same result as zeros for for string dtypes
#     151     z = zeros(1, dtype=res.dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# # ----------------------------------------------------------------------------------

# %% [markdown]
# ###### Applying Ravel to create 1D array, and applying OTSU thresholding

# %% [markdown]
# Let's create a flattened 1D array from our 4 dimensional array. Method mentioned at this URL.
# (https://stackoverflow.com/questions/13730468/from-nd-to-1d-arrays)

# %% [markdown]
# Professor mentioned array reshape function, also look into that as well.
#
# (Source: https://stackoverflow.com/questions/36384760/transforming-a-row-vector-into-a-column-vector-in-numpy)

# %%
flattened_row_array=raw_ct_scan_array.ravel()

# %% [markdown]
# Now, we're going to apply threshold_otsu function on our 1D Vector. (Save before executing, might crash)

# %%
flattened_row_array.shape

# %%
column_array=flattened_row_array.reshape(-1,1)

# %%
column_array

# %% [markdown]
# The resulting image is in grayscale. However, imshow, by default, uses a kind of heatmap (called vidris) to display the image intensities. Just specify the grayscale colormap as shown below:
# plt.imshow(mountain_r, cmap="gray")
# For all the possible colormaps, have a look at the colormap reference.
# (Source: https://stackoverflow.com/questions/39805697/skimage-why-does-rgb2gray-from-skimage-color-result-in-a-colored-image)

# %% [markdown]
# Shape of the flattened_array is (1442840576,). now it's (360710144,)

# %% [markdown]
# Apply thresholding

# %%
# %time thresh = threshold_otsu(column_array)

# %% [markdown]
# Wall time: 3.36 s (Recorded time to execute thresholding on the vector. Same timing on both row and column vectors.)

# %% [markdown]
# (On first run, PC freezed. After cold booting again, it worked the second time)

# %%
print(thresh)

# %% [markdown]
# Threshold value is SAME for both row and column vectors.

# %% [markdown]
# So now we have the threshold value in above thresh variable. We apply that using a simple binary operation, >

# %% [markdown]
# It basically sets all values above the threshold to TRUE, and everything else as FALSE. (Interpreted as 1 and 0)

# %%
thresholded_array = raw_ct_scan_array > thresh

# %% [markdown]
# Variable that stores the thresholded array

# %%
plt.imshow(thresholded_array[153,:,:],cmap="gray")

# %% [markdown]
# Refer this for file saving methods using PIL and scipy
#
# (Source: https://stackoverflow.com/questions/902761/saving-a-numpy-array-as-an-image)
#
# imsave('Path_to_your_folder/File_name.jpg',your_array) << Use this with skimage.io > imsave function
#
# https://stackoverflow.com/questions/10965417/how-to-convert-numpy-array-to-pil-image-applying-matplotlib-colormap << This worked

# %% [markdown]
# ###### Applying the morphological operations

# %% [markdown]
# Morphological operations are basically just transformations applied to a 2D image array that can be used for growing, shrinking, or finding edges in an image, etc.

# %% [markdown]
# We are interested in removing the tiny holes and gaps in our thresholded bone scans, and we apply Dilation to fill them in.

# %% [markdown]
#  In any given technique, we probe an image with a small shape or template called a structuring element, which defines the region of interest or neighborhood around a pixel.
#  (Source: http://scikit-image.org/docs/dev/auto_examples/xx_applications/plot_morphology.html)

# %%
from scipy import ndimage

# %%
# %time holes_filled_array= ndimage.binary_fill_holes(input=thresholded_array,structure=numpy.ones((5,5,5)))

# %%
plt.imshow(holes_filled_array[153,:,:],cmap='gray')

# %%
for img_index in range(0,344):
    im = Image.fromarray(numpy.uint8(holes_filled_array[img_index,:,:]*255))

    im.save("Morphological_Binary_hole_filling_5x5x5/hole_filled_5x5x5_slice(%d) .png" % (img_index+1))

# %% [markdown]
# If folder doesn't exist, make one with the name mentioned in the function else program will not work.

# %% [markdown]
# Our thresholded output is in the folder called Otsu_output.
